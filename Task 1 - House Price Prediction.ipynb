# %% [markdown]
# # **Name :- Vivek Patil**

# %% [markdown]
# # **Task 1 :- House Price Prediction**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Importing Dataset**

# %%
df=pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# **Data Wrangling**

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# **We can drop the columns "id" and "date" as they represent unique identifiers and have no relevance to the target variable house price.**

# %%
df = df.drop(["id","date"], axis = 1)

# %%
df.describe().T
# Out:
#                  count           mean            std         min         25%  \
# price          21613.0  540088.141767  367127.196483  75000.0000  321950.000
# bedrooms       21613.0       3.370842       0.930062      0.0000       3.000
# bathrooms      21613.0       2.114757       0.770163      0.0000       1.750
# sqft_living    21613.0    2079.899736     918.440897    290.0000    1427.000
# sqft_lot       21613.0   15106.967566   41420.511515    520.0000    5040.000
# floors         21613.0       1.494309       0.539989      1.0000       1.000
# waterfront     21613.0       0.007542       0.086517      0.0000       0.000
# view           21613.0       0.234303       0.766318      0.0000       0.000
# condition      21613.0       3.409430       0.650743      1.0000       3.000
# grade          21613.0       7.656873       1.175459      1.0000       7.000
# sqft_above     21613.0    1788.390691     828.090978    290.0000    1190.000
# sqft_basement  21613.0     291.509045     442.575043      0.0000       0.000
# yr_built       21613.0    1971.005136      29.373411   1900.0000    1951.000
# yr_renovated   21613.0      84.402258     401.679240      0.0000       0.000
# zipcode        21613.0   98077.939805      53.505026  98001.0000   98033.000
# lat            21613.0      47.560053       0.138564     47.1559      47.471
# long           21613.0    -122.213896       0.140828   -122.5190    -122.328
# sqft_living15  21613.0    1986.552492     685.391304    399.0000    1490.000
# sqft_lot15     21613.0   12768.455652   27304.179631    651.0000    5100.000
#
#                        50%         75%           max
# price          450000.0000  645000.000  7.700000e+06
# bedrooms            3.0000       4.000  3.300000e+01
# bathrooms           2.2500       2.500  8.000000e+00
# sqft_living      1910.0000    2550.000  1.354000e+04
# sqft_lot         7618.0000   10688.000  1.651359e+06
# floors              1.5000       2.000  3.500000e+00
# waterfront          0.0000       0.000  1.000000e+00
# view                0.0000       0.000  4.000000e+00
# condition           3.0000       4.000  5.000000e+00
# grade               7.0000       8.000  1.300000e+01
# sqft_above       1560.0000    2210.000  9.410000e+03
# sqft_basement       0.0000     560.000  4.820000e+03
# yr_built         1975.0000    1997.000  2.015000e+03
# yr_renovated        0.0000       0.000  2.015000e+03
# zipcode         98065.0000   98118.000  9.819900e+04
# lat                47.5718      47.678  4.777760e+01
# long             -122.2300    -122.125 -1.213150e+02
# sqft_living15    1840.0000    2360.000  6.210000e+03
# sqft_lot15       7620.0000   10083.000  8.712000e+05

# %% [markdown]
# **Now let's check for the null values.**

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# **As we can see above there are no null values in our dataset.**

# %% [markdown]
#  **Performing EDA**

# %%
cols = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement']

# %%
fig, axes = plt.subplots(1, len(cols), figsize=(20, 5))

for i, col in enumerate(cols):
    sns.boxplot(y=col, data=df, ax=axes[i])
    axes[i].set_title(col, fontsize=14)
    axes[i].set_ylabel('')

plt.tight_layout()

plt.show()

# %% [markdown]
# **As we can see above there are some outliers in the data.lets's deal with outliers**

# %%
# Remove outliers for price column
price_upper_limit = 5000000
df = df[df['price'] <= price_upper_limit]

# Remove outliers for bedrooms column
bedrooms_upper_limit = 8
df = df[df['bedrooms'] <= bedrooms_upper_limit]

# Remove outliers for bathrooms column
bathrooms_upper_limit = 6
df = df[(df['bathrooms'] < bathrooms_upper_limit) & (df['bathrooms'] >= 1)]

# Remove outliers for sqft_living column
sqft_living_upper_limit = 8500
df = df[df['sqft_living'] <= sqft_living_upper_limit]

# Remove outliers for sqft_lot column
sqft_lot_upper_limit = 60000
df = df[df['sqft_lot'] <= sqft_lot_upper_limit]

# Remove outliers for sqft_above column
sqft_above_upper_limit = 7000
df = df[df['sqft_above'] <= sqft_above_upper_limit]

# Remove outliers for sqft_basement column
sqft_basement_upper_limit = 3000
df = df[df['sqft_basement'] <= sqft_basement_upper_limit]

df.describe().transpose()
# Out:
#                  count           mean            std         min  \
# price          20784.0  533736.394246  347312.703345  78000.0000
# bedrooms       20784.0       3.369611       0.889687      0.0000
# bathrooms      20784.0       2.105863       0.748682      1.0000
# sqft_living    20784.0    2053.479022     871.828269    390.0000
# sqft_lot       20784.0    9499.097238    8527.613327    520.0000
# floors         20784.0       1.493962       0.541565      1.0000
# waterfront     20784.0       0.006977       0.083236      0.0000
# view           20784.0       0.226135       0.752969      0.0000
# condition      20784.0       3.412673       0.651061      1.0000
# grade          20784.0       7.641455       1.143215      4.0000
# sqft_above     20784.0    1762.621055     788.673418    390.0000
# sqft_basement  20784.0     290.857968     435.002590      0.0000
# yr_built       20784.0    1970.772998      29.496416   1900.0000
# yr_renovated   20784.0      83.555475     399.777777      0.0000
# zipcode        20784.0   98079.014338      53.828245  98001.0000
# lat            20784.0      47.562070       0.137223     47.1559
# long           20784.0    -122.219554       0.136184   -122.5110
# sqft_living15  20784.0    1970.689569     674.269216    399.0000
# sqft_lot15     20784.0    9323.111095   10808.161444    651.0000
#
#                          25%          50%          75%           max
# price          320000.000000  449950.0000  638000.0000  4.500000e+06
# bedrooms            3.000000       3.0000       4.0000  8.000000e+00
# bathrooms           1.500000       2.2500       2.5000  5.750000e+00
# sqft_living      1420.000000    1900.0000    2520.0000  7.710000e+03
# sqft_lot         5000.000000    7497.0000   10159.2500  5.986300e+04
# floors              1.000000       1.5000       2.0000  3.500000e+00
# waterfront          0.000000       0.0000       0.0000  1.000000e+00
# view                0.000000       0.0000       0.0000  4.000000e+00
# condition           3.000000       3.0000       4.0000  5.000000e+00
# grade               7.000000       7.0000       8.0000  1.300000e+01
# sqft_above       1190.000000    1550.0000    2180.0000  6.640000e+03
# sqft_basement       0.000000       0.0000     562.5000  2.850000e+03
# yr_built         1951.000000    1974.0000    1997.0000  2.015000e+03
# yr_renovated        0.000000       0.0000       0.0000  2.015000e+03
# zipcode         98033.000000   98070.0000   98118.0000  9.819900e+04
# lat                47.476275      47.5739      47.6786  4.777760e+01
# long             -122.330250    -122.2390    -122.1350 -1.213150e+02
# sqft_living15    1480.000000    1820.0000    2340.0000  6.110000e+03
# sqft_lot15       5040.000000    7500.0000    9768.2500  3.802790e+05

# %% [markdown]
# **Now let's see the countplot of the categorical variables.**

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

sns.countplot(x='bedrooms', data=df, ax=axes[0,0])
sns.countplot(x='bathrooms', data=df, ax=axes[0,1])
sns.countplot(x='floors', data=df, ax=axes[0,2])
sns.countplot(x='waterfront', data=df, ax=axes[1,0])
sns.countplot(x='view', data=df, ax=axes[1,1])

fig.suptitle("Count Plots for Bedrooms, Bathrooms, Floors, Waterfront, and View")

plt.show()

# %% [markdown]
# **Now let's see the correlation between the features.**

# %%
fig, ax = plt.subplots(figsize=(14, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# As per the analysis we can say that:
#
# The "bathrooms", "sqft_living", "grade", "sqft_living", and "sqft_above" features show a positive correlation with the target variable "price".
#
# "zipcode", "yr_built", and "condition" do not have a significant correlation with "price" and are not adding much value to the dataset. Therefore, we drop these features.

# %%
df = df.drop(["zipcode", "yr_built", "condition"], axis = 1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  grade  sqft_above  sqft_basement  yr_renovated      lat     long  \
# 0     0      7        1180              0             0  47.5112 -122.257
# 1     0      7        2170            400          1991  47.7210 -122.319
# 2     0      6         770              0             0  47.7379 -122.233
# 3     0      7        1050            910             0  47.5208 -122.393
# 4     0      8        1680              0             0  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
Floor_Value_counts = df["floors"].value_counts().to_frame()
Floor_Value_counts
# Out:
#      floors
# 1.0   10301
# 2.0    7899
# 1.5    1820
# 3.0     609
# 2.5     148
# 3.5       7

# %%
sns.boxplot(x= "waterfront", y = "price", data = df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
sns.regplot(x="sqft_above", y ="price", data = df)
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %% [markdown]
# As we can see above plot the size of the sqft_above increases then price of the house is also increases.

# %% [markdown]
#  **Normalize the Data**

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]
X = df[features]
Y = df['price']

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
X = norm_func(X)

# %% [markdown]
#  **Splitting the data into train and test**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=1)

# %% [markdown]
#  **Building a Model**

# %% [markdown]
# **1.Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(x_train, y_train)
linear_reg_score = linear_reg.score(x_test, y_test)
print(f"Linear Regression R^2: {linear_reg_score}")
# Out:
# Linear Regression R^2: 0.6571371122715969

# %% [markdown]
# **2.Ridge Regression**

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.1)
ridge_reg.fit(x_train, y_train)
ridge_reg_score = ridge_reg.score(x_test, y_test)
print(f"Ridge Regression R^2: {ridge_reg_score}")
# Out:
# Ridge Regression R^2: 0.6571494130468067

# %% [markdown]
# **3.Lasso Regression**

# %%
from sklearn.linear_model import Lasso

lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(x_train, y_train)
lasso_reg_score = lasso_reg.score(x_test, y_test)
print(f"Lasso Regression R^2: {lasso_reg_score}")
# Out:
# Lasso Regression R^2: 0.6571372148384217

# %% [markdown]
# **4.Decision Tree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree = DecisionTreeRegressor()
decision_tree.fit(x_train, y_train)
decision_tree_score = decision_tree.score(x_test, y_test)
print(f"Decision Tree R^2: {decision_tree_score}")
# Out:
# Decision Tree R^2: 0.6425249368693079

# %% [markdown]
# **5.Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest = RandomForestRegressor()
random_forest.fit(x_train, y_train)
random_forest_score = random_forest.score(x_test, y_test)
print(f"Random Forest R^2: {random_forest_score}")
# Out:
# Random Forest R^2: 0.8162653566075604

# %% [markdown]
# As we can see above the random forest regressor gave us the best score i.e. 81.45% .
#
# So now let's do the hyperparameter tunning so that we get the best parameters and best accuracy model.

# %% [markdown]
# **Hyper Parameter Tunning using GridSearchCV**

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
param_grid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False],
}

# %%
random_forest = RandomForestRegressor()

grid_search = HalvingGridSearchCV(estimator=random_forest, param_grid=param_grid,
                          verbose=3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# n_iterations: 6
# n_required_iterations: 6
# n_possible_iterations: 6
# min_resources_: 59
# max_resources_: 14548
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 360
# n_resources: 59
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.887, test=0.376) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.974, test=-7.255) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.904, test=0.635) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.917, test=0.702) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.920, test=0.434) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.951, test=0.693) total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.975, test=-4.780) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.933, test=0.560) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.939, test=0.700) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.942, test=0.450) total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.937, test=0.697) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.960, test=-4.134) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.942, test=0.726) total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.949, test=0.689) total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.932, test=0.460) total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.940, test=0.718) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.959, test=-4.005) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.943, test=0.638) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.941, test=0.655) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.927, test=0.490) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.885, test=0.622) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.868, test=-1.399) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.909, test=0.636) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.907, test=0.766) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.894, test=0.444) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.900, test=0.649) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.908, test=-5.099) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.902, test=0.640) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.896, test=0.746) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.881, test=0.492) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.911, test=0.684) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.910, test=-4.146) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.908, test=0.672) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.917, test=0.700) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.891, test=0.486) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.904, test=0.681) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.912, test=-4.742) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.912, test=0.633) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.908, test=0.687) total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.876, test=0.483) total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.829, test=0.511) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.886, test=-5.280) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.877, test=0.344) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.797, test=0.565) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.654, test=0.378) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.856, test=0.742) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.866, test=-3.256) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.895, test=0.649) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=0.696) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.752, test=0.419) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.857, test=0.693) total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.884, test=-6.903) total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.903, test=0.591) total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.825, test=0.711) total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.761, test=0.460) total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.869, test=0.676) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.884, test=-4.147) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.874, test=0.639) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.837, test=0.717) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.748, test=0.442) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.829, test=0.692) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.916, test=-2.960) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.961, test=0.634) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.926, test=0.579) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.867, test=0.526) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.869, test=0.700) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.904, test=-1.778) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.875, test=0.684) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.894, test=0.656) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.868, test=0.439) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.860, test=0.677) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.902, test=-3.428) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.883, test=0.692) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.901, test=0.726) total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.886, test=0.464) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.861, test=0.661) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.909, test=-3.193) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.865, test=0.681) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.906, test=0.700) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.884, test=0.473) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.819, test=0.654) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.885, test=-9.330) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.857, test=0.754) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.872, test=0.679) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.891, test=0.546) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.867, test=0.690) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.888, test=-4.733) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.850, test=0.594) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.883, test=0.676) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.870, test=0.470) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.851, test=0.682) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.894, test=-4.016) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.889, test=0.704) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.886, test=0.724) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.864, test=0.485) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.854, test=0.703) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.885, test=-3.500) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.870, test=0.679) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.893, test=0.692) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.870, test=0.464) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.746, test=0.597) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.891, test=-2.956) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.836, test=0.891) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.798, test=0.671) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.724, test=0.475) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.812, test=0.621) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.854, test=-3.862) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.828, test=0.712) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.801, test=0.693) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.769, test=0.411) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.832, test=0.704) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.861, test=-4.130) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.853, test=0.661) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.836, test=0.696) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.726, test=0.430) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.820, test=0.702) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.865, test=-5.006) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.853, test=0.703) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.826, test=0.718) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.732, test=0.443) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.667, test=0.801) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.866, test=-2.020) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.705, test=0.627) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.777, test=0.752) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.736, test=0.418) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.683, test=0.593) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.826, test=-1.868) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.736, test=0.692) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.790, test=0.708) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.729, test=0.396) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=(train=0.720, test=0.698) total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=(train=0.810, test=-1.385) total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=(train=0.722, test=0.618) total time=   0.2s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=(train=0.782, test=0.750) total time=   0.2s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=(train=0.732, test=0.386) total time=   0.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.715, test=0.671) total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.807, test=-1.123) total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.738, test=0.589) total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.781, test=0.755) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.741, test=0.397) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=(train=0.737, test=0.588) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=(train=0.856, test=-2.879) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=(train=0.688, test=0.644) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=(train=0.763, test=0.618) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=10;, score=(train=0.768, test=0.459) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=0.709, test=0.700) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=0.831, test=-1.958) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=0.721, test=0.634) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=0.778, test=0.722) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=(train=0.758, test=0.430) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.722, test=0.748) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.832, test=-1.924) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.755, test=0.661) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.786, test=0.688) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.751, test=0.415) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=(train=0.717, test=0.685) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=(train=0.831, test=-1.967) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=(train=0.733, test=0.605) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=(train=0.776, test=0.764) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=(train=0.739, test=0.407) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=(train=0.706, test=0.516) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=(train=0.857, test=-5.645) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=(train=0.725, test=0.649) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=(train=0.721, test=0.678) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=10;, score=(train=0.734, test=0.424) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.718, test=0.601) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.821, test=-1.956) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.731, test=0.608) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.764, test=0.707) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.690, test=0.372) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.702, test=0.637) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.813, test=-1.694) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.733, test=0.593) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.775, test=0.734) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.690, test=0.371) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=(train=0.708, test=0.672) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=(train=0.795, test=-1.125) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=(train=0.728, test=0.621) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=(train=0.756, test=0.725) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=(train=0.698, test=0.380) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.936, test=0.755) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.963, test=-3.402) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.906, test=0.211) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.927, test=0.654) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=10;, score=(train=0.906, test=0.426) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.949, test=0.717) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.960, test=-3.929) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.936, test=0.590) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.949, test=0.684) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=(train=0.920, test=0.475) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.953, test=0.662) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.974, test=-3.452) total time=   0.2s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.954, test=0.616) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.950, test=0.641) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.936, test=0.465) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.945, test=0.716) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.970, test=-4.407) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.929, test=0.609) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.944, test=0.692) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.938, test=0.490) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.860, test=0.677) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.931, test=-4.514) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.904, test=0.644) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.939, test=0.748) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=10;, score=(train=0.877, test=0.481) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.909, test=0.656) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.917, test=-3.388) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.902, test=0.636) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.900, test=0.657) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.897, test=0.488) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.890, test=0.638) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.893, test=-2.816) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.910, test=0.648) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.915, test=0.731) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.867, test=0.488) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.900, test=0.729) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.912, test=-3.908) total time=   0.4s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.907, test=0.659) total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.908, test=0.695) total time=   0.4s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.882, test=0.494) total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.831, test=0.573) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.859, test=-6.143) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.880, test=0.736) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.834, test=0.684) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=10;, score=(train=0.768, test=0.505) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.835, test=0.622) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.874, test=-4.956) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.864, test=0.584) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.830, test=0.715) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.769, test=0.466) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.843, test=0.670) total time=   0.2s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.868, test=-3.366) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.886, test=0.616) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.832, test=0.707) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=(train=0.729, test=0.439) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.847, test=0.712) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.887, test=-4.041) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.890, test=0.653) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.838, test=0.732) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.740, test=0.446) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.852, test=0.666) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.920, test=-5.264) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.867, test=0.665) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.903, test=0.607) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=10;, score=(train=0.892, test=0.501) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.868, test=0.689) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.924, test=-3.926) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.880, test=0.717) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.901, test=0.707) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=(train=0.895, test=0.506) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.865, test=0.678) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.915, test=-3.862) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.894, test=0.693) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.915, test=0.715) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.892, test=0.456) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.860, test=0.693) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.910, test=-3.599) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.899, test=0.679) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.911, test=0.712) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=(train=0.883, test=0.473) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.852, test=0.810) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.839, test=-1.750) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.872, test=0.471) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.866, test=0.570) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=10;, score=(train=0.804, test=0.509) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.858, test=0.703) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.886, test=-4.218) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.900, test=0.689) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.890, test=0.721) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=(train=0.859, test=0.482) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.857, test=0.716) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.890, test=-4.301) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.862, test=0.635) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.901, test=0.639) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=(train=0.853, test=0.490) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.855, test=0.677) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.887, test=-4.815) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.877, test=0.675) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.897, test=0.715) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.867, test=0.485) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.802, test=0.667) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.854, test=-4.261) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.886, test=0.350) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.825, test=0.661) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=10;, score=(train=0.716, test=0.328) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.817, test=0.732) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.865, test=-4.762) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.807, test=0.802) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.837, test=0.654) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=(train=0.729, test=0.422) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.829, test=0.728) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.862, test=-5.518) total time=   0.1s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.861, test=0.686) total time=   0.1s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.812, test=0.684) total time=   0.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=(train=0.735, test=0.418) total time=   0.1s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.825, test=0.699) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.870, test=-4.447) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.859, test=0.686) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.819, test=0.728) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=(train=0.742, test=0.430) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.734, test=0.580) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.821, test=-2.065) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.710, test=0.607) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.779, test=0.644) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=10;, score=(train=0.715, test=0.368) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.733, test=0.714) total time=   0.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=(train=0.823, test=-1.919) total time=   0.1s
# ...
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.879, test=0.722) total time=   1.0s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.874, test=0.744) total time=   1.0s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.871, test=0.675) total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=(train=0.884, test=0.763) total time=   1.0s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.962, test=0.701) total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.962, test=0.756) total time=   0.8s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.960, test=0.777) total time=   1.1s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.964, test=0.679) total time=   1.1s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.966, test=0.787) total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.908, test=0.690) total time=   1.1s
# [CV 2/5] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.904, test=0.749) total time=   1.1s
# [CV 3/5] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.893, test=0.759) total time=   1.1s
# [CV 4/5] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.911, test=0.681) total time=   1.1s
# [CV 5/5] END bootstrap=True, max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=(train=0.906, test=0.757) total time=   1.1s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.862, test=0.676) total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.874, test=0.727) total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.866, test=0.749) total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.861, test=0.671) total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=(train=0.877, test=0.752) total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.927, test=0.692) total time=   1.1s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.929, test=0.749) total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.776) total time=   1.4s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.682) total time=   1.1s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.771) total time=   1.1s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.865, test=0.675) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.869, test=0.719) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.861, test=0.750) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.865, test=0.671) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=(train=0.879, test=0.769) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.923, test=0.695) total time=   0.3s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.922, test=0.744) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.921, test=0.757) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.930, test=0.701) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.932, test=0.781) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.942, test=0.682) total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.942, test=0.761) total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.944, test=0.771) total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.946, test=0.690) total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.945, test=0.782) total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.871, test=0.682) total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.887, test=0.720) total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.873, test=0.747) total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.875, test=0.674) total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=40, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=(train=0.889, test=0.767) total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.908, test=0.696) total time=   0.4s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.900, test=0.743) total time=   0.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.893, test=0.760) total time=   0.3s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.906, test=0.679) total time=   0.3s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=(train=0.908, test=0.769) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.929, test=0.704) total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.742) total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.929, test=0.764) total time=   1.1s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.929, test=0.694) total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.935, test=0.778) total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.963, test=0.690) total time=   1.4s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.964, test=0.753) total time=   1.5s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.962, test=0.781) total time=   2.1s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.966, test=0.692) total time=   1.5s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.965, test=0.776) total time=   1.4s
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.922, test=0.686) total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.929, test=0.743) total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.926, test=0.768) total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.925, test=0.687) total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=(train=0.932, test=0.776) total time=   0.5s
# ----------
# iter: 4
# n_candidates: 5
# n_resources: 4779
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.907, test=0.779) total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.921, test=0.771) total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.911, test=0.774) total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.922, test=0.827) total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=(train=0.917, test=0.789) total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.937, test=0.778) total time=   4.1s
# [CV 2/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.947, test=0.782) total time=   3.3s
# [CV 3/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.943, test=0.777) total time=   3.2s
# [CV 4/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.950, test=0.835) total time=   3.5s
# [CV 5/5] END bootstrap=True, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=(train=0.944, test=0.791) total time=   3.9s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.949, test=0.785) total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.956, test=0.779) total time=   1.8s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.955, test=0.773) total time=   1.7s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.958, test=0.834) total time=   1.8s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.956, test=0.792) total time=   2.2s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.967, test=0.783) total time=   4.4s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.970, test=0.782) total time=   4.0s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.969, test=0.772) total time=   4.6s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.973, test=0.835) total time=   4.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.970, test=0.794) total time=   4.0s
# [CV 1/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.967, test=0.779) total time=   2.0s
# [CV 2/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.969, test=0.779) total time=   2.9s
# [CV 3/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.970, test=0.775) total time=   1.9s
# [CV 4/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.972, test=0.832) total time=   2.0s
# [CV 5/5] END bootstrap=True, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=(train=0.968, test=0.793) total time=   2.0s
# ----------
# iter: 5
# n_candidates: 2
# n_resources: 14337
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.960, test=0.825) total time=   6.2s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.960, test=0.824) total time=   5.4s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.960, test=0.813) total time=   5.9s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.960, test=0.802) total time=   5.7s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=(train=0.960, test=0.813) total time=   5.6s
# [CV 1/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.973, test=0.827) total time=  13.3s
# [CV 2/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.973, test=0.823) total time=  13.3s
# [CV 3/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.973, test=0.812) total time=  13.2s
# [CV 4/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.974, test=0.799) total time=  13.1s
# [CV 5/5] END bootstrap=True, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=(train=0.973, test=0.814) total time=  13.0s
# HalvingGridSearchCV(estimator=RandomForestRegressor(),
#                     param_grid={'bootstrap': [True, False],
#                                 'max_depth': [None, 10, 20, 30, 40],
#                                 'min_samples_leaf': [1, 2, 4],
#                                 'min_samples_split': [2, 5, 10],
#                                 'n_estimators': [10, 50, 100, 200]},
#                     verbose=3)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(min_samples_split=5)

# %%
best_model=grid_search.best_estimator_

# %%
best_model_score = best_model.score(x_test, y_test)
best_model_score
# Out:
# 0.8176262529097842

# %% [markdown]
# # **Conclusion :**

# %% [markdown]
# **So by using the Halving GridSearchCV we have got the best accuracy model i.e. 81.60%.**
#
# **This is the final model of our Housing Prices Predictor with the accuracy of 81.60%**
